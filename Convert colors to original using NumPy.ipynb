# %%
import numpy as np
from IPython.display import display
from PIL import Image

img = Image.open('image.png')

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1125x750 at 0x28E61B2E640>

# %%
img_array = np.array(img)
img_array
# Out:
# array([[[197, 182, 175],
#         [200, 185, 178],
#         [195, 181, 172],
#         ...,
#         [ 45,  59,  70],
#         [ 46,  60,  71],
#         [ 47,  61,  72]],
#
#        [[196, 181, 174],
#         [198, 183, 176],
#         [196, 182, 173],
#         ...,
#         [ 45,  59,  70],
#         [ 47,  61,  72],
#         [ 48,  62,  73]],
#
#        [[197, 182, 175],
#         [194, 179, 172],
#         [194, 180, 171],
#         ...,
#         [ 46,  60,  71],
#         [ 48,  62,  73],
#         [ 49,  63,  74]],
#
#        ...,
#
#        [[ 74,  76,  75],
#         [ 74,  76,  75],
#         [ 74,  76,  75],
#         ...,
#         [ 27,  40,  48],
#         [ 27,  40,  48],
#         [ 27,  40,  48]],
#
#        [[ 75,  77,  76],
#         [ 75,  77,  76],
#         [ 75,  77,  76],
#         ...,
#         [ 27,  40,  48],
#         [ 27,  40,  48],
#         [ 27,  40,  48]],
#
#        [[ 79,  81,  80],
#         [ 79,  81,  80],
#         [ 80,  82,  81],
#         ...,
#         [ 31,  44,  52],
#         [ 31,  44,  52],
#         [ 31,  44,  52]]], dtype=uint8)

# %%
mask = np.full(img_array.shape, 255)

color_img = np.subtract(mask, img_array).astype(img_array.dtype)

color_img
# Out:
# array([[[ 58,  73,  80],
#         [ 55,  70,  77],
#         [ 60,  74,  83],
#         ...,
#         [210, 196, 185],
#         [209, 195, 184],
#         [208, 194, 183]],
#
#        [[ 59,  74,  81],
#         [ 57,  72,  79],
#         [ 59,  73,  82],
#         ...,
#         [210, 196, 185],
#         [208, 194, 183],
#         [207, 193, 182]],
#
#        [[ 58,  73,  80],
#         [ 61,  76,  83],
#         [ 61,  75,  84],
#         ...,
#         [209, 195, 184],
#         [207, 193, 182],
#         [206, 192, 181]],
#
#        ...,
#
#        [[181, 179, 180],
#         [181, 179, 180],
#         [181, 179, 180],
#         ...,
#         [228, 215, 207],
#         [228, 215, 207],
#         [228, 215, 207]],
#
#        [[180, 178, 179],
#         [180, 178, 179],
#         [180, 178, 179],
#         ...,
#         [228, 215, 207],
#         [228, 215, 207],
#         [228, 215, 207]],
#
#        [[176, 174, 175],
#         [176, 174, 175],
#         [175, 173, 174],
#         ...,
#         [224, 211, 203],
#         [224, 211, 203],
#         [224, 211, 203]]], dtype=uint8)

# %%
display(Image.fromarray(color_img))
# Out:
# <PIL.Image.Image image mode=RGB size=1125x750 at 0x28E420884F0>
